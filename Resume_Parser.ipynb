# %%
# !python --version
# Out:
# Python 3.10.3

# %%
pip install -U gensim==3.6.0
# Out:
# ...
#   Using cached gensim-3.6.0-cp310-cp310-win_amd64.whl
# ...
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.0
#     Uninstalling gensim-4.3.0:
#       Successfully uninstalled gensim-4.3.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords

# %%
import docx2txt

# %%
resume = docx2txt.process("C:\\Users\\M.Gopal\\M.Srinitha_Resume_5g3.docx")
text_resume = str(resume)#Summarize the text with ratio 0.1 (10% of the total words.)
#summarize(text_resume, ratio=0.1)

# %%
text_resume
# Out:
# "+91 8247389179\n\n\uf0e0 srimamidimada@gmail.com\n\n\uf0e1 https://www.linkedin.com/in/srinitha- mamidimada-801b50203\n\n\uf041 Patancheru\n\n\nM.Srinitha\n\nStudent\n\n\n\n\n\n\n\nCAREER OBJECTIVE\n\nTo work in a challenging organization that offers diverse job responsibilities in knowing where I can fully employ my proven organizational and creative capabilities and zeal for learning to develop and empower my knowledge as well as my skill sets.\n\nEDUCATION\n\n\tB.Tech. in Computer Science\tDec '20 - Aug '24\n\n\n\nB V Raju Institute of Technology\n\nCGPA-8.40\n\n\nNarsapur,Telangana\n\n\n\n\tINTERMEDIATE\tJul '18 - Aug '20\n\n\n\nSRI CHAITANYA JUNIOR COLLEGE\n\nPERCENTAGE-96.6\n\n\nMadinaguda,Telangana\n\n\n\n\tSCHOOL\tJul '05 - Apr '18\n\n\n\nST JOSEPH'S HIGH SCHOOL\n\nCGPA-9.5\n\nLEADERSHIP AND AWARDS\n\n\nPatancheru, Telangana\n\n\n\n\n\n\n\n\n\nValidated in c and python by CISCO\n\nCertificate of Appreciation in AccioWars Coding Contest by AccioJob.\n\nCertified in Python (Bu
# ...

# %%
text = input("Enter Job description :")
# Out:
# Enter Job description :A Software Developer is a professional who is charged with designing and coding software for businesses and consumers alike. They work closely with clients to determine what they need, then use programming languages like Java or C++ to create programs. They must have critical thinking skills, as well as strong problem-solving abilities.

# %%
text = str(text)

# %%
text
# Out:
# 'A Software Developer is a professional who is charged with designing and coding software for businesses and consumers alike. They work closely with clients to determine what they need, then use programming languages like Java or C++ to create programs. They must have critical thinking skills, as well as strong problem-solving abilities.'

# %%
text_list = [text_resume, text]
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
count_matrix = cv.fit_transform(text_list)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# get the match percentage
matchPercentage = cosine_similarity(count_matrix)[0][1] * 100
matchPercentage = round(matchPercentage, 2) # round to two decimal
print("Your resume matches about "+ str(matchPercentage)+ "% of the job description.")
# outputYour resume matches about 24.16% of the job description.#keywords
print(keywords(text, ratio=0.25)) 
# gives you the keywords of the job description
# Out:
# Your resume matches about 24.16% of the job description.
# programming
# programs
# software
# thinking
# problem
